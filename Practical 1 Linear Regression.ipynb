# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load Boston housing dataset from CSV
boston_data = pd.read_csv('boston.csv')

# Separate features and target variable
X = boston_data.drop('MEDV', axis=1)  # Features ( you can use SalePrice columns according to dataset)
y = boston_data['MEDV']  # Target variable

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Build the neural network model
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model
model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1)

# Evaluate the model on test data
loss, mae = model.evaluate(X_test, y_test)
print("Mean Absolute Error on Test Set:", mae)

# Make predictions
predictions = model.predict(X_test)

# Print predictions
print("Predictions:", predictions)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 1s 23ms/step - loss: 22.1648 - mean_absolute_error: 22.1648 - val_loss: 19.9787 - val_mean_absolute_error: 19.9787
# Epoch 2/100
# 11/11 [==============================] - 0s 9ms/step - loss: 19.4030 - mean_absolute_error: 19.4030 - val_loss: 16.4982 - val_mean_absolute_error: 16.4982
# Epoch 3/100
# 11/11 [==============================] - 0s 8ms/step - loss: 15.0988 - mean_absolute_error: 15.0988 - val_loss: 11.2291 - val_mean_absolute_error: 11.2291
# Epoch 4/100
# 11/11 [==============================] - 0s 8ms/step - loss: 9.3448 - mean_absolute_error: 9.3448 - val_loss: 5.6596 - val_mean_absolute_error: 5.6596
# Epoch 5/100
# 11/11 [==============================] - 0s 8ms/step - loss: 7.0020 - mean_absolute_error: 7.0020 - val_loss: 5.3109 - val_mean_absolute_error: 5.3109
# Epoch 6/100
# 11/11 [==============================] - 0s 8ms/step - loss: 5.4442 - mean_absolute_error: 5.4442 - val_loss: 4.2967 - val_mean_absolute_error: 4.2967
# Epoch 7/100
# 11/11 [==============================] - 0s 8ms/step - loss: 4.0369 - mean_absolute_error: 4.0369 - val_loss: 3.8228 - val_mean_absolute_error: 3.8228
# Epoch 8/100
# 11/11 [==============================] - 0s 8ms/step - loss: 3.5748 - mean_absolute_error: 3.5748 - val_loss: 3.6828 - val_mean_absolute_error: 3.6828
# Epoch 9/100
# 11/11 [==============================] - 0s 8ms/step - loss: 3.3873 - mean_absolute_error: 3.3873 - val_loss: 3.5601 - val_mean_absolute_error: 3.5601
# Epoch 10/100
# 11/11 [==============================] - 0s 7ms/step - loss: 3.1927 - mean_absolute_error: 3.1927 - val_loss: 3.3650 - val_mean_absolute_error: 3.3650
# Epoch 11/100
# 11/11 [==============================] - 0s 7ms/step - loss: 3.0177 - mean_absolute_error: 3.0177 - val_loss: 3.2995 - val_mean_absolute_error: 3.2995
# Epoch 12/100
# 11/11 [==============================] - 0s 7ms/step - loss: 2.9071 - mean_absolute_error: 2.9071 - val_loss: 3.2361 - val_mean_absolute_error: 3.2361
# Epoch 13/100
# 11/11 [==============================] - 0s 6ms/step - loss: 2.8402 - mean_absolute_error: 2.8402 - val_loss: 3.2845 - val_mean_absolute_error: 3.2845
# Epoch 14/100
# 11/11 [==============================] - 0s 5ms/step - loss: 2.9750 - mean_absolute_error: 2.9750 - val_loss: 3.2095 - val_mean_absolute_error: 3.2095
# Epoch 15/100
# 11/11 [==============================] - 0s 6ms/step - loss: 2.7075 - mean_absolute_error: 2.7075 - val_loss: 3.1494 - val_mean_absolute_error: 3.1494
# Epoch 16/100
# 11/11 [==============================] - 0s 6ms/step - loss: 2.6834 - mean_absolute_error: 2.6834 - val_loss: 3.1941 - val_mean_absolute_error: 3.1941
# Epoch 17/100
# 11/11 [==============================] - 0s 5ms/step - loss: 2.5706 - mean_absolute_error: 2.5706 - val_loss: 3.1445 - val_mean_absolute_error: 3.1445
# Epoch 18/100
# 11/11 [==============================] - 0s 6ms/step - loss: 2.5295 - mean_absolute_error: 2.5295 - val_loss: 3.0712 - val_mean_absolute_error: 3.0712
# Epoch 19/100
# 11/11 [==============================] - 0s 5ms/step - loss: 2.4976 - mean_absolute_error: 2.4976 - val_loss: 2.9739 - val_mean_absolute_error: 2.9739
# Epoch 20/100
# 11/11 [==============================] - 0s 5ms/step - loss: 2.5010 - mean_absolute_error: 2.5010 - val_loss: 3.0068 - val_mean_absolute_error: 3.0068
# Epoch 21/100
# 11/11 [==============================] - 0s 6ms/step - loss: 2.4162 - mean_absolute_error: 2.4162 - val_loss: 3.0127 - val_mean_absolute_error: 3.0127
# Epoch 22/100
# 11/11 [==============================] - 0s 5ms/step - loss: 2.4015 - mean_absolute_error: 2.4015 - val_loss: 2.9833 - val_mean_absolute_error: 2.9833
# Epoch 23/100
# 11/11 [==============================] - 0s 6ms/step - loss: 2.3496 - mean_absolute_error: 2.3496 - val_loss: 2.9256 - val_mean_absolute_error: 2.9256
# Epoch 24/100
# 11/11 [==============================] - 0s 5ms/step - loss: 2.3367 - mean_absolute_error: 2.3367 - val_loss: 2.9782 - val_mean_absolute_error: 2.9782
# Epoch 25/100
# 11/11 [==============================] - 0s 5ms/step - loss: 2.3210 - mean_absolute_error: 2.3210 - val_loss: 2.9934 - val_mean_absolute_error: 2.9934
# Epoch 26/100
# 11/11 [==============================] - 0s 6ms/step - loss: 2.3647 - mean_absolute_error: 2.3647 - val_loss: 3.0228 - val_mean_absolute_error: 3.0228
# Epoch 27/100
# 11/11 [==============================] - 0s 6ms/step - loss: 2.3622 - mean_absolute_error: 2.3622 - val_loss: 2.8298 - val_mean_absolute_error: 2.8298
# Epoch 28/100
# 11/11 [==============================] - 0s 5ms/step - loss: 2.3257 - mean_absolute_error: 2.3257 - val_loss: 2.8314 - val_mean_absolute_error: 2.8314
# Epoch 29/100
# 11/11 [==============================] - 0s 5ms/step - loss: 2.2488 - mean_absolute_error: 2.2488 - val_loss: 2.9208 - val_mean_absolute_error: 2.9208
# Epoch 30/100
# 11/11 [==============================] - 0s 5ms/step - loss: 2.2758 - mean_absolute_error: 2.2758 - val_loss: 2.9919 - val_mean_absolute_error: 2.9919
# Epoch 31/100
# 11/11 [==============================] - 0s 6ms/step - loss: 2.2223 - mean_absolute_error: 2.2223 - val_loss: 2.8055 - val_mean_absolute_error: 2.8055
# Epoch 32/100
# 11/11 [==============================] - 0s 5ms/step - loss: 2.3528 - mean_absolute_error: 2.3528 - val_loss: 2.7786 - val_mean_absolute_error: 2.7786
# Epoch 33/100
# 11/11 [==============================] - 0s 6ms/step - loss: 2.1909 - mean_absolute_error: 2.1909 - val_loss: 2.8474 - val_mean_absolute_error: 2.8474
# Epoch 34/100
# 11/11 [==============================] - 0s 6ms/step - loss: 2.2085 - mean_absolute_error: 2.2085 - val_loss: 2.9315 - val_mean_absolute_error: 2.9315
# Epoch 35/100
# 11/11 [==============================] - 0s 5ms/step - loss: 2.3360 - mean_absolute_error: 2.3360 - val_loss: 2.8097 - val_mean_absolute_error: 2.8097
# Epoch 36/100
# 11/11 [==============================] - 0s 6ms/step - loss: 2.2134 - mean_absolute_error: 2.2134 - val_loss: 2.8357 - val_mean_absolute_error: 2.8357
# Epoch 37/100
# 11/11 [==============================] - 0s 6ms/step - loss: 2.1294 - mean_absolute_error: 2.1294 - val_loss: 2.7940 - val_mean_absolute_error: 2.7940
# Epoch 38/100
# 11/11 [==============================] - 0s 5ms/step - loss: 2.1656 - mean_absolute_error: 2.1656 - val_loss: 2.7277 - val_mean_absolute_error: 2.7277
# Epoch 39/100
# 11/11 [==============================] - 0s 6ms/step - loss: 2.1126 - mean_absolute_error: 2.1126 - val_loss: 2.7273 - val_mean_absolute_error: 2.7273
# Epoch 40/100
# 11/11 [==============================] - 0s 9ms/step - loss: 2.0761 - mean_absolute_error: 2.0761 - val_loss: 2.7471 - val_mean_absolute_error: 2.7471
# Epoch 41/100
# 11/11 [==============================] - 0s 7ms/step - loss: 2.0858 - mean_absolute_error: 2.0858 - val_loss: 2.7551 - val_mean_absolute_error: 2.7551
# Epoch 42/100
# 11/11 [==============================] - 0s 5ms/step - loss: 2.1038 - mean_absolute_error: 2.1038 - val_loss: 2.8188 - val_mean_absolute_error: 2.8188
# Epoch 43/100
# 11/11 [==============================] - 0s 5ms/step - loss: 2.0946 - mean_absolute_error: 2.0946 - val_loss: 2.7741 - val_mean_absolute_error: 2.7741
# Epoch 44/100
# 11/11 [==============================] - 0s 5ms/step - loss: 2.0272 - mean_absolute_error: 2.0272 - val_loss: 2.8326 - val_mean_absolute_error: 2.8326
# Epoch 45/100
# 11/11 [==============================] - 0s 5ms/step - loss: 2.1295 - mean_absolute_error: 2.1295 - val_loss: 2.6912 - val_mean_absolute_error: 2.6912
# Epoch 46/100
# 11/11 [==============================] - 0s 6ms/step - loss: 2.0951 - mean_absolute_error: 2.0951 - val_loss: 2.6087 - val_mean_absolute_error: 2.6087
# Epoch 47/100
# 11/11 [==============================] - 0s 5ms/step - loss: 2.0900 - mean_absolute_error: 2.0900 - val_loss: 2.6918 - val_mean_absolute_error: 2.6918
# Epoch 48/100
# 11/11 [==============================] - 0s 6ms/step - loss: 2.0849 - mean_absolute_error: 2.0849 - val_loss: 2.6899 - val_mean_absolute_error: 2.6899
# Epoch 49/100
# 11/11 [==============================] - 0s 6ms/step - loss: 2.0244 - mean_absolute_error: 2.0244 - val_loss: 2.6593 - val_mean_absolute_error: 2.6593
# Epoch 50/100
# 11/11 [==============================] - 0s 6ms/step - loss: 2.0533 - mean_absolute_error: 2.0533 - val_loss: 2.6064 - val_mean_absolute_error: 2.6064
# Epoch 51/100
# 11/11 [==============================] - 0s 5ms/step - loss: 2.0310 - mean_absolute_error: 2.0310 - val_loss: 2.7500 - val_mean_absolute_error: 2.7500
# Epoch 52/100
# 11/11 [==============================] - 0s 5ms/step - loss: 2.0818 - mean_absolute_error: 2.0818 - val_loss: 2.7660 - val_mean_absolute_error: 2.7660
# Epoch 53/100
# 11/11 [==============================] - 0s 6ms/step - loss: 2.0419 - mean_absolute_error: 2.0419 - val_loss: 2.7274 - val_mean_absolute_error: 2.7274
# Epoch 54/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.9809 - mean_absolute_error: 1.9809 - val_loss: 2.6011 - val_mean_absolute_error: 2.6011
# Epoch 55/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.9548 - mean_absolute_error: 1.9548 - val_loss: 2.7215 - val_mean_absolute_error: 2.7215
# Epoch 56/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.9930 - mean_absolute_error: 1.9930 - val_loss: 2.6874 - val_mean_absolute_error: 2.6874
# Epoch 57/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.9773 - mean_absolute_error: 1.9773 - val_loss: 2.6738 - val_mean_absolute_error: 2.6738
# Epoch 58/100
# 11/11 [==============================] - 0s 6ms/step - loss: 2.0969 - mean_absolute_error: 2.0969 - val_loss: 2.6135 - val_mean_absolute_error: 2.6135
# Epoch 59/100
# 11/11 [==============================] - 0s 5ms/step - loss: 2.0759 - mean_absolute_error: 2.0759 - val_loss: 2.6765 - val_mean_absolute_error: 2.6765
# Epoch 60/100
# 11/11 [==============================] - 0s 7ms/step - loss: 2.0362 - mean_absolute_error: 2.0362 - val_loss: 2.6889 - val_mean_absolute_error: 2.6889
# Epoch 61/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.9407 - mean_absolute_error: 1.9407 - val_loss: 2.6667 - val_mean_absolute_error: 2.6667
# Epoch 62/100
# 11/11 [==============================] - 0s 11ms/step - loss: 1.9167 - mean_absolute_error: 1.9167 - val_loss: 2.6441 - val_mean_absolute_error: 2.6441
# Epoch 63/100
# 11/11 [==============================] - 0s 7ms/step - loss: 1.9102 - mean_absolute_error: 1.9102 - val_loss: 2.7055 - val_mean_absolute_error: 2.7055
# Epoch 64/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.8939 - mean_absolute_error: 1.8939 - val_loss: 2.6647 - val_mean_absolute_error: 2.6647
# Epoch 65/100
# 11/11 [==============================] - 0s 11ms/step - loss: 1.8839 - mean_absolute_error: 1.8839 - val_loss: 2.6271 - val_mean_absolute_error: 2.6271
# Epoch 66/100
# 11/11 [==============================] - 0s 7ms/step - loss: 1.8897 - mean_absolute_error: 1.8897 - val_loss: 2.5162 - val_mean_absolute_error: 2.5162
# Epoch 67/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.8748 - mean_absolute_error: 1.8748 - val_loss: 2.5530 - val_mean_absolute_error: 2.5530
# Epoch 68/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.8531 - mean_absolute_error: 1.8531 - val_loss: 2.5921 - val_mean_absolute_error: 2.5921
# Epoch 69/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.8973 - mean_absolute_error: 1.8973 - val_loss: 2.6412 - val_mean_absolute_error: 2.6412
# Epoch 70/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.9184 - mean_absolute_error: 1.9184 - val_loss: 2.7191 - val_mean_absolute_error: 2.7191
# Epoch 71/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.9166 - mean_absolute_error: 1.9166 - val_loss: 2.6054 - val_mean_absolute_error: 2.6054
# Epoch 72/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.9500 - mean_absolute_error: 1.9500 - val_loss: 2.5283 - val_mean_absolute_error: 2.5283
# Epoch 73/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.8148 - mean_absolute_error: 1.8148 - val_loss: 2.5439 - val_mean_absolute_error: 2.5439
# Epoch 74/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.8266 - mean_absolute_error: 1.8266 - val_loss: 2.5439 - val_mean_absolute_error: 2.5439
# Epoch 75/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.8425 - mean_absolute_error: 1.8425 - val_loss: 2.5825 - val_mean_absolute_error: 2.5825
# Epoch 76/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.8790 - mean_absolute_error: 1.8790 - val_loss: 2.4623 - val_mean_absolute_error: 2.4623
# Epoch 77/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.8128 - mean_absolute_error: 1.8128 - val_loss: 2.5146 - val_mean_absolute_error: 2.5146
# Epoch 78/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.8506 - mean_absolute_error: 1.8506 - val_loss: 2.5451 - val_mean_absolute_error: 2.5451
# Epoch 79/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.8347 - mean_absolute_error: 1.8347 - val_loss: 2.5001 - val_mean_absolute_error: 2.5001
# Epoch 80/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.7904 - mean_absolute_error: 1.7904 - val_loss: 2.5896 - val_mean_absolute_error: 2.5896
# Epoch 81/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.8205 - mean_absolute_error: 1.8205 - val_loss: 2.3745 - val_mean_absolute_error: 2.3745
# Epoch 82/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.8095 - mean_absolute_error: 1.8095 - val_loss: 2.4407 - val_mean_absolute_error: 2.4407
# Epoch 83/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.7732 - mean_absolute_error: 1.7732 - val_loss: 2.5526 - val_mean_absolute_error: 2.5526
# Epoch 84/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.8241 - mean_absolute_error: 1.8241 - val_loss: 2.3899 - val_mean_absolute_error: 2.3899
# Epoch 85/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.7842 - mean_absolute_error: 1.7842 - val_loss: 2.4084 - val_mean_absolute_error: 2.4084
# Epoch 86/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.7746 - mean_absolute_error: 1.7746 - val_loss: 2.4365 - val_mean_absolute_error: 2.4365
# Epoch 87/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.7084 - mean_absolute_error: 1.7084 - val_loss: 2.5230 - val_mean_absolute_error: 2.5230
# Epoch 88/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.7027 - mean_absolute_error: 1.7027 - val_loss: 2.4766 - val_mean_absolute_error: 2.4766
# Epoch 89/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.6919 - mean_absolute_error: 1.6919 - val_loss: 2.4517 - val_mean_absolute_error: 2.4517
# Epoch 90/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.7457 - mean_absolute_error: 1.7457 - val_loss: 2.4336 - val_mean_absolute_error: 2.4336
# Epoch 91/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.7604 - mean_absolute_error: 1.7604 - val_loss: 2.4153 - val_mean_absolute_error: 2.4153
# Epoch 92/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.7449 - mean_absolute_error: 1.7449 - val_loss: 2.3980 - val_mean_absolute_error: 2.3980
# Epoch 93/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.7737 - mean_absolute_error: 1.7737 - val_loss: 2.4232 - val_mean_absolute_error: 2.4232
# Epoch 94/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.6923 - mean_absolute_error: 1.6923 - val_loss: 2.4467 - val_mean_absolute_error: 2.4467
# Epoch 95/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.7309 - mean_absolute_error: 1.7309 - val_loss: 2.4375 - val_mean_absolute_error: 2.4375
# Epoch 96/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.7447 - mean_absolute_error: 1.7447 - val_loss: 2.4930 - val_mean_absolute_error: 2.4930
# Epoch 97/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.7394 - mean_absolute_error: 1.7394 - val_loss: 2.4297 - val_mean_absolute_error: 2.4297
# Epoch 98/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.7245 - mean_absolute_error: 1.7245 - val_loss: 2.4222 - val_mean_absolute_error: 2.4222
# Epoch 99/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.6246 - mean_absolute_error: 1.6246 - val_loss: 2.3918 - val_mean_absolute_error: 2.3918
# Epoch 100/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.6552 - mean_absolute_error: 1.6552 - val_loss: 2.3634 - val_mean_absolute_error: 2.3634
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0053 - mean_absolute_error: 2.0053
# Mean Absolute Error on Test Set: 2.0052690505981445
# 4/4 [==============================] - 0s 2ms/step
# Predictions: [[27.251774 ]
#  [33.205322 ]
#  [15.053047 ]
#  [25.556227 ]
#  [15.930854 ]
#  [19.979206 ]
#  [17.050346 ]
#  [14.70478  ]
#  [23.378853 ]
#  [19.609938 ]
#  [19.670856 ]
#  [18.454031 ]
#  [ 4.4317975]
#  [19.373674 ]
#  [18.031717 ]
#  [23.81791  ]
#  [19.05416  ]
#  [10.493974 ]
#  [46.18547  ]
#  [13.419175 ]
#  [25.076979 ]
#  [26.442091 ]
#  [14.728953 ]
#  [24.744276 ]
#  [16.609098 ]
#  [17.467432 ]
#  [20.538149 ]
#  [12.052344 ]
#  [20.691471 ]
#  [18.989672 ]
#  [23.759554 ]
#  [22.843267 ]
#  [18.894018 ]
#  [23.531322 ]
#  [14.716521 ]
#  [15.93721  ]
#  [33.860756 ]
#  [19.887999 ]
#  [22.767221 ]
#  [25.231043 ]
#  [18.250013 ]
#  [30.0094   ]
#  [49.85991  ]
#  [18.889467 ]
#  [27.251646 ]
#  [15.831999 ]
#  [14.872161 ]
#  [26.963419 ]
#  [19.652687 ]
#  [27.713203 ]
#  [19.425219 ]
#  [35.76128  ]
#  [16.869211 ]
#  [26.647078 ]
#  [43.79042  ]
#  [22.656454 ]
#  [16.07768  ]
#  [33.154392 ]
#  [25.522814 ]
#  [17.038927 ]
#  [25.422182 ]
#  [35.310757 ]
#  [30.241077 ]
#  [15.94914  ]
#  [23.036612 ]
#  [18.538427 ]
#  [15.449511 ]
#  [23.46769  ]
#  [29.030844 ]
#  [12.361581 ]
#  [21.991646 ]
#  [26.288881 ]
#  [ 9.077482 ]
#  [19.934015 ]
#  [21.236979 ]
#  [ 5.553287 ]
#  [20.326233 ]
#  [47.125816 ]
#  [10.913437 ]
#  [ 9.950698 ]
#  [20.920177 ]
#  [11.888589 ]
#  [19.090857 ]
#  [11.188662 ]
#  [19.905533 ]
#  [26.798868 ]
#  [15.755136 ]
#  [23.407866 ]
#  [24.169428 ]
#  [19.567526 ]
#  [23.998796 ]
#  [ 7.211567 ]
#  [19.806555 ]
#  [19.473516 ]
#  [30.74795  ]
#  [20.826834 ]
#  [25.38723  ]
#  [ 9.228384 ]
#  [10.8804455]
#  [11.764116 ]
#  [23.645441 ]
#  [22.036644 ]]
